# %%
import pandas as pd
df=pd.read_excel('IDSP_29th_Week_Outbreak_Report_2025.xlsx')

# %%
df.head()
# Out:
#             state        district                  disease  no_of_cases  \
# 0  Andhra Pradesh  Visakhapatanam  Acute Diarrheal Disease           22
# 1           Assam          Cachar  Fever of Unknown Origin           19
# 2           Assam      Hailakandi  Fever of Unknown Origin           24
# 3           Assam        Tinsukia            Leptospirosis            7
# 4           Bihar           Patna  Acute Diarrheal Disease           20
#
#    no_of_deaths start_of_outbreak date_of_reporting              status  \
# 0             0        17-07-2025        17-07-2025       Under Control
# 1             0        16-07-2025        17-07-2025  Under Surveillance
# 2             0        18-07-2025        18-07-2025  Under Surveillance
# 3             0        17-07-2025        18-07-2025  Under Surveillance
# 4             0        17-07-2025        19-07-2025  Under Surveillance
#
#                                               action
# ...

# %%
df['state'].value_counts()
# Out:
# state
# Madhya Pradesh       9
# Kerala               7
# Odisha               5
# Chhattisgarh         4
# Jharkhand            4
# Assam                3
# Gujarat              3
# Bihar                2
# Maharashtra          2
# Tamil Nadu           2
# Uttar Pradesh        2
# West Bengal          2
# Andhra Pradesh       1
# Jammu and Kashmir    1
# Karnataka            1
# Punjab               1
# Name: count, dtype: int64
